# %%
import datetime
import numpy as np
import pandas as pd
# %matplotlib inline
import pandas_datareader.data as web
import yfinance as yf

# %%
stock=["DIS","ROK","BUD","XOM","CVS","WFC","AB","SPOT","PII","UNH"]
start = datetime.datetime(2018,11,12)
end = datetime.datetime(2019,11,12)
df = web.get_data_yahoo(stock, start=start , end=end)[["Open","Close"]]
df
# Out:
# Attributes        Open                                               \
# Symbols            DIS         ROK        BUD        XOM        CVS
# Date
# 2018-11-12  118.000000  169.550003  73.209999  81.660004  79.830002
# 2018-11-13  117.110001  165.860001  73.720001  79.800003  80.959999
# 2018-11-14  117.440002  167.940002  74.800003  78.860001  81.099998
# 2018-11-15  116.489998  166.500000  76.750000  76.669998  79.379997
# 2018-11-16  116.529999  171.820007  77.250000  78.370003  79.580002
# ...                ...         ...        ...        ...        ...
# 2019-11-07  132.350006  180.429993  78.709999  72.029999  71.940002
# 2019-11-08  140.220001  176.639999  78.339996  71.610001  71.800003
# 2019-11-11  137.500000  177.119995  78.309998  70.209999  71.980003
# 2019-11-12  138.029999  201.029999  79.760002  70.269997  71.550003
# 2019-11-13  138.580002  195.679993  80.250000  69.019997  71.830002
#
# Attributes                                                            \
# ...

# %%
df.describe()
# Out:
# Attributes        Open                                                  \
# Symbols            DIS         ROK         BUD         XOM         CVS
# count       253.000000  253.000000  253.000000  253.000000  253.000000
# mean        126.301621  165.738972   84.310672   74.570593   61.354783
# std          12.329564   11.216601    8.920176    4.400427    7.402564
# min         100.489998  142.779999   65.150002   66.180000   52.009998
# 25%         113.099998  157.250000   77.029999   70.980003   54.889999
# 50%         131.440002  164.259995   83.989998   75.040001   60.860001
# 75%         136.509995  175.080002   92.230003   78.000000   65.459999
# max         145.759995  201.029999  101.919998   83.190002   81.099998
#
# Attributes                                                              \
# Symbols            WFC          AB        SPOT         PII         UNH
# count       253.000000  253.000000  253.000000  253.000000  253.000000
# ...

# %%
df_close = df['Close']
iqr =df_close.describe()["PII"]["75%"] - df_close.describe()["PII"]["25%"]
bin_width = (2*iqr)*((len(df_close["PII"])**(-1/3)))
bin_width
# Out:
# 2.4222466650432084

# %%
bin_edges= np.arange(min(df_close["DIS"]),max(df_close["DIS"]),bin_width)
bin_edges
# Out:
# array([100.34999847, 102.77224514, 105.1944918 , 107.61673847,
#        110.03898513, 112.4612318 , 114.88347846, 117.30572513,
#        119.72797179, 122.15021846, 124.57246512, 126.99471179,
#        129.41695845, 131.83920512, 134.26145178, 136.68369845,
#        139.10594511, 141.52819178, 143.95043844, 146.37268511])

# %%
hist= np.array(df_close["DIS"])
hist
# Out:
# array([116.69999695, 116.84999847, 117.12000275, 117.11000061,
#        116.19000244, 115.41999817, 111.87000275, 113.02999878,
#        112.08000183, 112.55000305, 113.90000153, 116.09999847,
#        116.61000061, 115.48999786, 115.73999786, 112.87000275,
#        114.33000183, 111.98000336, 111.86000061, 111.97000122,
#        112.20999908, 113.38999939, 112.19999695, 110.62000275,
#        109.44999695, 109.22000122, 107.        , 104.22000122,
#        100.34999847, 105.83000183, 106.51999664, 107.30000305,
#        109.65000153, 108.97000122, 106.33000183, 109.61000061,
#        110.55999756, 111.41999817, 112.66999817, 112.80000305,
#        112.65000153, 112.41999817, 111.76000214, 110.91000366,
#        111.01000214, 111.04000092, 110.59999847, 111.12000275,
#        110.55000305, 111.08999634, 110.80999756, 110.90000153,
#        110.12999725, 111.51999664, 111.30000305, 111.80000305,
#        112.66000366, 111.41000366, 110.94999695, 111.51000214,
# ...

# %%
hist, bin_edges = np.histogram()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-b227b867b091> in <module>
# ----> 1 hist, bin_edges = np.histogram()
#
# TypeError: histogram() missing 1 required positional argument: 'a'

# %%
import matplotlib.pyplot as plt
plt.hist(df_close["PII"], bins = 100)
# Out:
# (array([1., 1., 0., 0., 0., 0., 0., 1., 0., 1., 1., 2., 0., 1., 0., 1., 2.,
#         2., 2., 0., 1., 2., 1., 1., 5., 1., 1., 1., 2., 1., 2., 4., 2., 4.,
#         5., 3., 3., 8., 6., 5., 6., 6., 7., 5., 2., 9., 6., 7., 8., 4., 3.,
#         4., 5., 1., 7., 7., 6., 3., 3., 9., 4., 2., 3., 2., 4., 1., 2., 3.,
#         1., 1., 1., 2., 4., 1., 2., 1., 1., 7., 1., 1., 2., 1., 1., 1., 2.,
#         3., 0., 0., 0., 0., 0., 3., 0., 4., 4., 2., 0., 0., 2., 3.]),
#  array([ 72.33999634,  72.6509964 ,  72.96199646,  73.27299652,
#          73.58399658,  73.89499664,  74.2059967 ,  74.51699677,
#          74.82799683,  75.13899689,  75.44999695,  75.76099701,
#          76.07199707,  76.38299713,  76.69399719,  77.00499725,
#          77.31599731,  77.62699738,  77.93799744,  78.2489975 ,
#          78.55999756,  78.87099762,  79.18199768,  79.49299774,
#          79.8039978 ,  80.11499786,  80.42599792,  80.73699799,
#          81.04799805,  81.35899811,  81.66999817,  81.98099823,
# ...

# %%
df.head()
# Out:
# Attributes        Open                                               \
# Symbols            DIS         ROK        BUD        XOM        CVS
# Date
# 2018-11-12  118.000000  169.550003  73.209999  81.660004  79.830002
# 2018-11-13  117.110001  165.860001  73.720001  79.800003  80.959999
# 2018-11-14  117.440002  167.940002  74.800003  78.860001  81.099998
# 2018-11-15  116.489998  166.500000  76.750000  76.669998  79.379997
# 2018-11-16  116.529999  171.820007  77.250000  78.370003  79.580002
#
# Attributes                                                           \
# Symbols           WFC         AB        SPOT        PII         UNH
# Date
# 2018-11-12  53.130001  29.840000  136.839996  90.970001  276.000000
# 2018-11-13  52.619999  29.760000  132.270004  91.199997  272.579987
# 2018-11-14  53.139999  30.250000  134.259995  93.089996  269.290009
# 2018-11-15  51.540001  29.940001  132.479996  92.620003  264.000000
# ...

# %%
import math
df["log_DIS"] = df["Close"]["DIS"]/ df["Open"]["DIS"]
df["log_ROK"] = df["Close"]["ROK"]/ df["Open"]["ROK"]
df["log_BUD"] = df["Close"]["BUD"]/ df["Open"]["BUD"]
df["log_XOM"] = df["Close"]["XOM"]/ df["Open"]["XOM"]
df["log_CVS"] = df["Close"]["CVS"]/ df["Open"]["CVS"]
df["log_WFC"] = df["Close"]["WFC"]/ df["Open"]["WFC"]
df["log_AB"]  = df["Close"]["AB"]/  df["Open"]["AB"]
df["log_SPOT"]= df["Close"]["SPOT"]/df["Open"]["SPOT"]
df["log_PII"] = df["Close"]["PII"]/ df["Open"]["PII"]
df["log_UNH"] = df["Close"]["UNH"]/ df["Open"]["UNH"]
df.head()
# Out:
# Attributes        Open                                               \
# Symbols            DIS         ROK        BUD        XOM        CVS
# Date
# 2018-11-12  118.000000  169.550003  73.209999  81.660004  79.830002
# 2018-11-13  117.110001  165.860001  73.720001  79.800003  80.959999
# 2018-11-14  117.440002  167.940002  74.800003  78.860001  81.099998
# 2018-11-15  116.489998  166.500000  76.750000  76.669998  79.379997
# 2018-11-16  116.529999  171.820007  77.250000  78.370003  79.580002
#
# Attributes                                                           ...  \
# Symbols           WFC         AB        SPOT        PII         UNH  ...
# Date                                                                 ...
# 2018-11-12  53.130001  29.840000  136.839996  90.970001  276.000000  ...
# 2018-11-13  52.619999  29.760000  132.270004  91.199997  272.579987  ...
# 2018-11-14  53.139999  30.250000  134.259995  93.089996  269.290009  ...
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(df["log_DIS"], bins = 'fd')
plt.hist(df["log_ROK"], bins = 'fd')
plt.hist(df["log_BUD"], bins = 'fd')
plt.hist(df["log_XOM"], bins = 'fd')
# Out:
# (array([ 5., 11., 12., 16., 23., 36., 39., 42., 31., 19.,  9.,  5.,  3.,
#          0.,  0.,  2.]),
#  array([0.97345751, 0.97743962, 0.98142174, 0.98540385, 0.98938596,
#         0.99336808, 0.99735019, 1.00133231, 1.00531442, 1.00929654,
#         1.01327865, 1.01726076, 1.02124288, 1.02522499, 1.02920711,
#         1.03318922, 1.03717134]),
#  <a list of 16 Patch objects>)

# %%
pip install ipywidgets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
jupyter nbextension enable --py widgetsnbextension
# Out:
#   File "<ipython-input-2-98201c4d83e5>", line 1
#     jupyter nbextension enable --py widgetsnbextension
#                       ^
# SyntaxError: invalid syntax

# %%
jupyter labextension install @jupyter-widgets/jupyterlab-manager
# Out:
#   File "<ipython-input-3-c2a3404c0366>", line 1
#     jupyter labextension install @jupyter-widgets/jupyterlab-manager
#                        ^
# SyntaxError: invalid syntax

# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
# Attributes        Open                                               \
# Symbols            DIS         ROK        BUD        XOM        CVS
# Date
# 2018-11-12  118.000000  169.550003  73.209999  81.660004  79.830002
# 2018-11-13  117.110001  165.860001  73.720001  79.800003  80.959999
# 2018-11-14  117.440002  167.940002  74.800003  78.860001  81.099998
# 2018-11-15  116.489998  166.500000  76.750000  76.669998  79.379997
# 2018-11-16  116.529999  171.820007  77.250000  78.370003  79.580002
#
# Attributes                                                           \
# Symbols           WFC         AB        SPOT        PII         UNH
# Date
# 2018-11-12  53.130001  29.840000  136.839996  90.970001  276.000000
# 2018-11-13  52.619999  29.760000  132.270004  91.199997  272.579987
# 2018-11-14  53.139999  30.250000  134.259995  93.089996  269.290009
# 2018-11-15  51.540001  29.940001  132.479996  92.620003  264.000000
# ...

# %%
df['Close']["DIS"]
# Out:
# Date
# 2018-11-12    116.699997
# 2018-11-13    116.849998
# 2018-11-14    117.120003
# 2018-11-15    117.110001
# 2018-11-16    116.190002
#                  ...
# 2019-11-07    132.960007
# 2019-11-08    137.960007
# 2019-11-11    136.740005
# 2019-11-12    138.580002
# 2019-11-13    148.720001
# Name: DIS, Length: 253, dtype: float64

# %%
@interact
def show_articles_more_than(column=["DIS","ROK","BUD",'XOM','CVS'] ,x=150):
    return df.loc[df["Close"][column] > x]
# Out:
# interactive(children=(Dropdown(description='column', options=('DIS', 'ROK', 'BUD', 'XOM', 'CVS'), value='DIS')…

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
def f(x):
    return x
q = interact(f, x=["DIS","ROK","BUD","XOM",'CVS']);
# Out:
# interactive(children=(Dropdown(description='x', options=('DIS', 'ROK', 'BUD', 'XOM', 'CVS'), value='DIS'), Out…

# %%
display(w)
# Out:
# <function __main__.f(x)>

# %%
from IPython.display import display
def f(a, b):
    display(a + b)
    return a+b

# %%
w = interactive(f, a=10, b=20)

# %%
w.children
# Out:
# (IntSlider(value=10, description='a', max=30, min=-10),
#  IntSlider(value=20, description='b', max=60, min=-20),
#  Output())

# %%
display(w)
# Out:
# interactive(children=(IntSlider(value=10, description='a', max=30, min=-10), IntSlider(value=20, description='…

# %%
a = widgets.Dropdown(options=["DIS","ROK","BUD","XOM",'CVS'])
b = widgets.Dropdown(options=["DIS","ROK","BUD","XOM",'CVS','Log_returns'], value = 'Log_returns')

ui = widgets.HBox([a, b])
def f(a, b):
    print((a, b))

out = widgets.interactive_output(f, {'a': a, 'b': b})

display(ui, out)
# Out:
# ...
# Output()

# %%
w = interact(f,x=["ABC","DEF"]);
# Out:
# interactive(children=(Dropdown(description='x', options=('ABC', 'DEF'), value='ABC'), Output()), _dom_classes=…

# %%
display(w)
# Out:
# <function __main__.f(x)>

# %%
widgets.DatePicker(
    description='Pick a Date',
    disabled=False
)
# Out:
# DatePicker(value=None, description='Pick a Date')

# %%
plt.hist(df["Close"]["DIS"])
# Out:
# (array([ 2., 17., 67., 17.,  0.,  5., 57., 47., 34.,  7.]),
#  array([100.34999847, 105.18699875, 110.02399902, 114.8609993 ,
#         119.69799957, 124.53499985, 129.37200012, 134.2090004 ,
#         139.04600067, 143.88300095, 148.72000122]),
#  <a list of 10 Patch objects>)

# %%
import matplotlib.pyplot as plt
c = widgets.Dropdown(options = ["May-Oct",'Nov-Apr'])
a = widgets.Dropdown(options=["DIS","ROK","BUD","XOM",'CVS'])
b = widgets.Dropdown(options=["DIS","ROK","BUD","XOM",'CVS','Log_returns'], value = 'Log_returns')
def f(a, b, c):
    if a=="DIS" and b=="DIS":
        plt.hist(df['Close']["DIS"], bins = 'fd')
    elif a=="DIS" and b== "XOM":
        print("output goes here")

out = widgets.interactive_output(f, {'a': a, 'b': b, 'c': c})

widgets.HBox([widgets.VBox([a, b, c]), out])

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
disc= df["Close"]["DIS"]
diso= df["Open"]["DIS"]
disc=disc.values
diso= diso.values

# %%
df['Close'].plot(x='DIS', y='ROK', style='o')  
plt.title('DIS vs ROK')  
plt.xlabel('Stock')  
plt.ylabel('#')  
plt.show()

# %%
X=df["Close"]["DIS"].values.reshape(-1,1)
y=df["Open"]["DIS"].values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train)

# %%
print(regressor.intercept_)
print(regressor.coef_)

# %%
y_pred = regressor.predict(X_test)

# %%
dfpredict = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
dfpredict

# %%
df1 = dfpredict.head(25)
df1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
plt.scatter(X_test, y_test,  color='gray')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 1.260245989550803
# Mean Squared Error: 3.909850907614709
# Root Mean Squared Error: 1.9773342933390674
